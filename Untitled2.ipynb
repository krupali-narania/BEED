# %% [markdown]
# <a href="https://colab.research.google.com/github/krupali-narania/BEED/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4be43644-3b1a-4cd9-b3f2-ae8e82e2df58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4be43644-3b1a-4cd9-b3f2-ae8e82e2df58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('BEED_Data.csv')
print(df.head())
# Out:
#     X1   X2   X3   X4   X5   X6  X7  X8  X9  X10  X11  X12  X13  X14  X15  \
# 0    4    7   18   25   28   27  20  10 -10  -18  -20  -16   13   32   12
# 1   87  114  120  106   76   54  28   5 -19  -49  -85 -102 -100  -89  -61
# 2 -131 -133 -140 -131 -123 -108 -58 -51 -70  -77  -76  -76  -73  -57  -40
# 3   68  104   73   34  -12  -26 -38 -36 -67  -88  -25   31   18   -4    6
# 4  -67  -90  -97  -94  -86  -71 -43 -11  23   46   58   50   39   19   -9
#
#    X16  y
# 0   10  0
# 1  -21  0
# 2  -14  0
# 3  -29  0
# 4  -41  0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize

# Plot sample EEG signal from first row
plt.figure(figsize=(10,4))
plt.plot(df.iloc[0, :-1])
plt.title("Sample EEG Signal (First Row)")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# Class distribution bar chart
plt.figure(figsize=(6,4))
sns.countplot(df['y'])
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# FFT spectrum of the first EEG sample
sample_signal = df.iloc[0, :-1].values.astype(float)
fft_vals = np.fft.fft(sample_signal)
freqs = np.fft.fftfreq(len(fft_vals))

plt.figure(figsize=(10,4))
plt.stem(freqs[:len(freqs)//2], np.abs(fft_vals)[:len(freqs)//2], use_line_collection=True)
plt.title("FFT Spectrum")
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.show()

# Example confusion matrix plot (replace y_true & y_pred with real predictions)
y_true = df['y'].values
np.random.seed(42)
y_pred = np.random.choice(np.unique(y_true), size=len(y_true))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Example ROC curves (for multi-class)
y_bin = label_binarize(y_true, classes=np.unique(y_true))
y_pred_proba = np.random.rand(*y_bin.shape)  # dummy probability predictions

plt.figure(figsize=(6,5))
for i in range(y_bin.shape[1]):
    fpr, tpr, _ = roc_curve(y_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC={roc_auc:.2f})")
plt.plot([0,1],[0,1],'k--')
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3549191191.py in <cell line: 0>()
#      27
#      28 plt.figure(figsize=(10,4))
# ---> 29 plt.stem(freqs[:len(freqs)//2], np.abs(fft_vals)[:len(freqs)//2], use_line_collection=True)
#      30 plt.title("FFT Spectrum")
#      31 plt.xlabel("Frequency")
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize

# Plot sample EEG signal
plt.figure(figsize=(10,4))
plt.plot(df.iloc[0, :-1])
plt.title("Sample EEG Signal (First Row)")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# Class distribution bar chart
plt.figure(figsize=(6,4))
sns.countplot(df['y'])
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# FFT spectrum without deprecated argument
sample_signal = df.iloc[0, :-1].values.astype(float)
fft_vals = np.fft.fft(sample_signal)
freqs = np.fft.fftfreq(len(fft_vals))

plt.figure(figsize=(10,4))
plt.stem(freqs[:len(freqs)//2], np.abs(fft_vals)[:len(freqs)//2])
plt.title("FFT Spectrum")
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.show()

# Dummy example confusion matrix - replace predictions with actual later
y_true = df['y'].values
np.random.seed(42)
y_pred = np.random.choice(np.unique(y_true), size=len(y_true))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Example ROC curves (multi-class)
y_bin = label_binarize(y_true, classes=np.unique(y_true))
y_pred_proba = np.random.rand(*y_bin.shape)  # dummy probabilities

plt.figure(figsize=(6,5))
for i in range(y_bin.shape[1]):
    fpr, tpr, _ = roc_curve(y_bin[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC={roc_auc:.2f})")
plt.plot([0,1],[0,1],'k--')
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# %%
# !ls -R
# Out:
# .:
# sample_data
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !ls
# Out:
# sample_data

# %%
# !ls /content
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/BEED_Data.csv')
print(df.head())
# Out:
#     X1   X2   X3   X4   X5   X6  X7  X8  X9  X10  X11  X12  X13  X14  X15  \
# 0    4    7   18   25   28   27  20  10 -10  -18  -20  -16   13   32   12
# 1   87  114  120  106   76   54  28   5 -19  -49  -85 -102 -100  -89  -61
# 2 -131 -133 -140 -131 -123 -108 -58 -51 -70  -77  -76  -76  -73  -57  -40
# 3   68  104   73   34  -12  -26 -38 -36 -67  -88  -25   31   18   -4    6
# 4  -67  -90  -97  -94  -86  -71 -43 -11  23   46   58   50   39   19   -9
#
#    X16  y
# 0   10  0
# 1  -21  0
# 2  -14  0
# 3  -29  0
# 4  -41  0

# %%
print("Checking for missing values:")
print(df.isnull().sum())

df = df.dropna()  # Or impute if needed

from sklearn.preprocessing import StandardScaler
X = df.drop('y', axis=1)
y = df['y']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot(cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.show()
# Out:
# Checking for missing values:
# X1     0
# X2     0
# X3     0
# X4     0
# X5     0
# X6     0
# X7     0
# X8     0
# X9     0
# X10    0
# X11    0
# X12    0
# X13    0
# X14    0
# X15    0
# X16    0
# y      0
# dtype: int64
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       400
#            1       0.98      0.97      0.98       400
#            2       0.92      0.94      0.93       400
#            3       0.94      0.93      0.93       400
#
#     accuracy                           0.96      1600
#    macro avg       0.96      0.96      0.96      1600
# weighted avg       0.96      0.96      0.96      1600
